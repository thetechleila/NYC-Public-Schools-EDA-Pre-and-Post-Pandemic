# %% [markdown]
# # NYC High School Graduation Rates for the Classes 2016-2023
# ___

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np

# %%
#Store NYC public school graduation dataset file path in variable for readability
grad_path = ("/Users/sa14/Desktop/EducationCapstone Sprint0 EDA/data/NYCTotalGraduationResults_Cohorts2012-19_Clases2016-23.csv")

#Load NYC public school grad dataset csv as a dataframe
df = pd.read_csv(grad_path)

# %%
#Get first 5 rows of dataset
df.head()
# Out:
#   Report Category      Category  Cohort Year         Cohort  # Total Cohort  \
# 0        Citywide  All Students         2019  4 year August           69893
# 1        Citywide  All Students         2018  4 year August           70912
# 2        Citywide  All Students         2017  4 year August           72663
# 3        Citywide  All Students         2016  4 year August           73565
# 4        Citywide  All Students         2015  4 year August           73772
#
#   # Grads % Grads # Total Regents % Total Regents of Cohort  \
# 0   58503    83.7           58295                      83.4
# 1   59374    83.7           59110                      83.4
# 2   60055    82.6           59683                      82.1
# 3   58704    79.8           57734                      78.5
# 4   57035    77.3           51848                      70.3
#
#   % Total Regents of Grads  ... % Local of Cohort % Local of Grads  \
# 0                     99.6  ...               0.3              0.4
# ...

# %%
#Get definite count of rows and columns
df.shape
# Out:
# (1130, 27)

# %% [markdown]
# **There are 1130 rows and 27 columns.**

# %%
#Get column data types (dtype), overall count of each present dtype, and memory usage
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1130 entries, 0 to 1129
# Data columns (total 27 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Report Category                       1130 non-null   object
#  1   Category                              1130 non-null   object
#  2   Cohort Year                           1130 non-null   int64
#  3   Cohort                                1130 non-null   object
#  4   # Total Cohort                        1130 non-null   int64
#  5   # Grads                               1130 non-null   object
#  6   % Grads                               1130 non-null   object
#  7   # Total Regents                       1130 non-null   object
#  8   % Total Regents of Cohort             1130 non-null   object
#  9   % Total Regents of Grads              1130 non-null   object
#  10  # Advanced Regents                    1130 non-null   object
# ...
