# %% [markdown]
# # NYC Public School Student Demographics from 2016 to 2023
# ___

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np

# %%
#Store NYC public school demographic dataset file path in variable for readability
demo_path = ("/Users/sa14/Desktop/EducationCapstone Sprint0 EDA/data/2019-20_NYCSchools_DemographicSnapshot.csv")

#Load NYC public school demographic dataset csv as a dataframe
df = pd.read_csv(demo_path)

# %%
#Get the first rows of the NYC public school demographic dataset dataframe
df.head()
# Out:
#       Year  Total Enrollment  Grade 3K+PK (Half Day & Full Day)  Grade K  \
# 0  2015-16           1133963                              71847    84386
# 1  2016-17           1141232                              72553    82517
# 2  2017-18           1135334                              71528    81588
# 3  2018-19           1126501                              73904    78627
# 4  2019-20           1131868                              87480    78587
#
#    Grade 1  Grade 2  Grade 3  Grade 4  Grade 5  Grade 6  ...  \
# 0    87804    86930    85309    81287    79581    76798  ...
# 1    86008    86279    85050    84185    80563    78985  ...
# 2    83578    83978    84363    83367    83277    79114  ...
# 3    81908    81205    81706    82510    82044    81289  ...
# 4    79171    80298    79555    80287    81513    80250  ...
#
#    % Multiple Race Categories Not Represented  # White  % White  \
# 0                                       0.021   167465    0.148
# ...

# %%
#Get the count of rows and columns for the dataset
df.shape
# Out:
# (5, 37)

# %%
#Get overall count of null/NaN values in the dataset
null_count = df.isnull().sum()
print("Null Values by Column\n\n",null_count)
# Out:
# Null Values by Column
#
#  Year                                          0
# Total Enrollment                              0
# Grade 3K+PK (Half Day & Full Day)             0
# Grade K                                       0
# Grade 1                                       0
# Grade 2                                       0
# Grade 3                                       0
# Grade 4                                       0
# Grade 5                                       0
# Grade 6                                       0
# Grade 7                                       0
# Grade 8                                       0
# Grade 9                                       0
# Grade 10                                      0
# Grade 11                                      0
# Grade 12                                      0
# # Female                                      0
# % Female                                      0
# # Male                                        0
# ...

# %% [markdown]
# **No null values exist across this entire dataset.**

# %%
#Get column data types (dtype), overall count of each present dtype, and memory usage
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 37 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Year                                        5 non-null      object
#  1   Total Enrollment                            5 non-null      int64
#  2   Grade 3K+PK (Half Day & Full Day)           5 non-null      int64
#  3   Grade K                                     5 non-null      int64
#  4   Grade 1                                     5 non-null      int64
#  5   Grade 2                                     5 non-null      int64
#  6   Grade 3                                     5 non-null      int64
#  7   Grade 4                                     5 non-null      int64
#  8   Grade 5                                     5 non-null      int64
#  9   Grade 6                                     5 non-null      int64
# ...

# %%
#Determine the descriptive statistics of the dataset such as the mean, median, percentiles, etc.
df.describe()
# Out:
#        Total Enrollment  Grade 3K+PK (Half Day & Full Day)       Grade K  \
# count      5.000000e+00                           5.000000      5.000000
# mean       1.133780e+06                       75462.400000  81141.000000
# std        5.353043e+03                        6779.870006   2523.208374
# min        1.126501e+06                       71528.000000  78587.000000
# 25%        1.131868e+06                       71847.000000  78627.000000
# 50%        1.133963e+06                       72553.000000  81588.000000
# 75%        1.135334e+06                       73904.000000  82517.000000
# max        1.141232e+06                       87480.000000  84386.000000
#
#             Grade 1       Grade 2       Grade 3       Grade 4      Grade 5  \
# count      5.000000      5.000000      5.000000      5.000000      5.00000
# mean   83693.800000  83738.000000  83196.600000  82327.200000  81395.60000
# std     3387.752825   2956.046092   2487.013932   1566.082118   1410.66183
# ...

# %% [markdown]
# **The 2019-2020 Demographic Snapshot covers citywide (Manhattan, Bronx, Brooklyn, Queens, Staten Island) student demographics from these academic years:**
#
# - **2015-2016**
# - **2016-2017**
# - **2017-2018**
# - **2018-2019**
# - **2019-2020**
#
# **All data information is separated into 5 rows corresponding with the academic year**
#
# **The 2019-2020 Demographic Snapshot spans grades K-12.**

# %% [markdown]
# ___
# ## Univariate and Bivariate Analyses
# ___

# %%
#Examine total student enrollment for the 5 school year ranges
total_enrollment_df = df[["Year","Total Enrollment"]]
total_enrollment_df
# Out:
#       Year  Total Enrollment
# 0  2015-16           1133963
# 1  2016-17           1141232
# 2  2017-18           1135334
# 3  2018-19           1126501
# 4  2019-20           1131868
